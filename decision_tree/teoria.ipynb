# %% [markdown]
# Olhe para o exemplo abaixo, não podemos apenas traçar uma linha reta e separar as classes, precisamos avalidar cada uma:
#
#
# <img src= "attachment:60e85733-fafe-4822-90af-6403c999c189.png" width="300">
#
# Considerando X0 e X1 como features de um modelo, a arvoré de decisão vai avaliar aspectos de cada feature levando as para um caminho:
#
# <img src="attachment:25341e57-03fc-4f2b-8bac-2a8864193365.png" width="450">
